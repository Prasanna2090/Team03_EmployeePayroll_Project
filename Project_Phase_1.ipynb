# %%
from google.colab import drive
drive.mount('/content/drive', force_remount=True)
# Out:
# Mounted at /content/drive

# %%
project_directory = '/content/drive/MyDrive/python_data/'
project_directory
# Out:
# '/content/drive/MyDrive/python_data/'

# %%
ls /content
# Out:
# drive/  sample_data/

# %%
ls /content/drive
# Out:
# MyDrive/

# %%
ls /content/drive/MyDrive/python_data/
# Out:
# car_data.csv  Employee_Payroll.xlsx

# %%
# importing the necessary libraries 
import pandas as pd 
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
# Fetching the data set and storing in Employee_payroll variable
Employee_payroll = pd.read_excel("drive/MyDrive/python_data/Employee_Payroll.xlsx")
Employee_payroll
# Out:
#         Fiscal Year  Fiscal Quarter Fiscal Period First Name   Last Name  \
# 0              2016               1        2016Q1     AMRITH       AAKRE
# 1              2016               2        2016Q2     AMRITH       AAKRE
# 2              2016               3        2016Q3     AMRITH       AAKRE
# 3              2016               4        2016Q4     AMRITH       AAKRE
# 4              2017               1        2017Q1     AMRITH       AAKRE
# ...             ...             ...           ...        ...         ...
# 234294         2018               2        2018Q2      NORMA  AMOFA-LOZA
# 234295         2018               2        2018Q2      FRANK    PHILLIPS
# 234296         2018               1        2018Q1    CYNTHIA    KENDRICK
# 234297         2018               1        2018Q1      LAURA      TOLEDO
# 234298         2018               2        2018Q2      NAKIA  WASHINGTON
#
#        Middle Init                          Bureau   Office  \
# 0                K                State's Attorney 1,250.00
# 1                K                State's Attorney 1,250.00
# 2                K                State's Attorney 1,250.00
# 3                K                State's Attorney 1,250.00
# 4                K                State's Attorney 1,250.00
# ...            ...                             ...      ...
# 234294          E.                 STATES ATTORNEY 1,250.00
# 234295           J        DEPT. OF FACILITIES/MGMT 1,200.00
# 234296           R           ADULT PROBATION DEPT. 1,280.00
# 234297         NaN  AMBULATORY COMMUNITY HLTH NTWK 4,893.00
# 234298         NaN  JUVENILE TEMPORARY DETENT.CNTR 1,440.00
#
#                            Office Name  Job Code  \
# 0                      STATES ATTORNEY      1172
# 1                      STATES ATTORNEY      1172
# 2                      STATES ATTORNEY      1172
# 3                      STATES ATTORNEY      1172
# 4                      STATES ATTORNEY      1172
# ...                                ...       ...
# 234294                 STATES ATTORNEY      1172
# 234295        DEPT. OF FACILITIES/MGMT      2452
# 234296           ADULT PROBATION DEPT.      1567
# 234297  AMBULATORY COMMUNITY HLTH NTWK      5296
# 234298  JUVENILE TEMPORARY DETENT.CNTR        48
#
#                            Job Title  Base Pay  Position ID  \
# 0         Assistant State's Attorney 20,088.00      9510200
# 1         Assistant State's Attorney 23,436.00      9510200
# 2         Assistant State's Attorney 20,422.82      9510200
# 3         Assistant State's Attorney 23,904.80      9510200
# 4         Assistant State's Attorney 20,745.80      9510200
# ...                              ...       ...          ...
# 234294    Assistant State's Attorney 19,001.95      9510048
# 234295         Operating Engineer II 27,098.40      9502511
# 234296  Adult Probation Officer- PSB 19,217.40      9512421
# 234297             Medical Assistant  9,698.80      9519643
# 234298  Administrative Assistant III 12,872.44      1400088
#
#                          Employee Identifier Original Hire Date
# 0       6ac7ba3e-d286-44f5-87a0-191dc415e23c         2005-05-16
# 1       6ac7ba3e-d286-44f5-87a0-191dc415e23c         2005-05-16
# 2       6ac7ba3e-d286-44f5-87a0-191dc415e23c         2005-05-16
# 3       6ac7ba3e-d286-44f5-87a0-191dc415e23c         2005-05-16
# 4       6ac7ba3e-d286-44f5-87a0-191dc415e23c         2005-05-16
# ...                                      ...                ...
# 234294  ac4574b1-d301-44a7-a220-d3aafb5e9ec3         2013-01-28
# 234295  9839f658-99a7-4b0c-a338-411d2fc2e8c9         1988-01-05
# 234296  709a5fed-c9a2-4fe6-9d4d-439bd389b5b8         1985-07-01
# 234297  8967b2f6-c6eb-40b6-836b-f52c6954325c         2016-08-08
# 234298  286c35d5-ca24-4ea7-bb7f-39dff92f78a4         2011-06-06
#
# [234299 rows x 15 columns]

# %%
# First 5 rows of the data set
Employee_payroll.head()
# Out:
#    Fiscal Year  Fiscal Quarter Fiscal Period First Name Last Name Middle Init  \
# 0         2016               1        2016Q1     AMRITH     AAKRE           K
# 1         2016               2        2016Q2     AMRITH     AAKRE           K
# 2         2016               3        2016Q3     AMRITH     AAKRE           K
# 3         2016               4        2016Q4     AMRITH     AAKRE           K
# 4         2017               1        2017Q1     AMRITH     AAKRE           K
#
#              Bureau   Office      Office Name  Job Code  \
# 0  State's Attorney 1,250.00  STATES ATTORNEY      1172
# 1  State's Attorney 1,250.00  STATES ATTORNEY      1172
# 2  State's Attorney 1,250.00  STATES ATTORNEY      1172
# 3  State's Attorney 1,250.00  STATES ATTORNEY      1172
# 4  State's Attorney 1,250.00  STATES ATTORNEY      1172
#
#                     Job Title  Base Pay  Position ID  \
# 0  Assistant State's Attorney 20,088.00      9510200
# 1  Assistant State's Attorney 23,436.00      9510200
# 2  Assistant State's Attorney 20,422.82      9510200
# 3  Assistant State's Attorney 23,904.80      9510200
# 4  Assistant State's Attorney 20,745.80      9510200
#
#                     Employee Identifier Original Hire Date
# 0  6ac7ba3e-d286-44f5-87a0-191dc415e23c         2005-05-16
# 1  6ac7ba3e-d286-44f5-87a0-191dc415e23c         2005-05-16
# 2  6ac7ba3e-d286-44f5-87a0-191dc415e23c         2005-05-16
# 3  6ac7ba3e-d286-44f5-87a0-191dc415e23c         2005-05-16
# 4  6ac7ba3e-d286-44f5-87a0-191dc415e23c         2005-05-16

# %%
# Last 5 rows of the data set
Employee_payroll.tail()
# Out:
#         Fiscal Year  Fiscal Quarter Fiscal Period First Name   Last Name  \
# 234294         2018               2        2018Q2      NORMA  AMOFA-LOZA
# 234295         2018               2        2018Q2      FRANK    PHILLIPS
# 234296         2018               1        2018Q1    CYNTHIA    KENDRICK
# 234297         2018               1        2018Q1      LAURA      TOLEDO
# 234298         2018               2        2018Q2      NAKIA  WASHINGTON
#
#        Middle Init                          Bureau   Office  \
# 234294          E.                 STATES ATTORNEY 1,250.00
# 234295           J        DEPT. OF FACILITIES/MGMT 1,200.00
# 234296           R           ADULT PROBATION DEPT. 1,280.00
# 234297         NaN  AMBULATORY COMMUNITY HLTH NTWK 4,893.00
# 234298         NaN  JUVENILE TEMPORARY DETENT.CNTR 1,440.00
#
#                            Office Name  Job Code  \
# 234294                 STATES ATTORNEY      1172
# 234295        DEPT. OF FACILITIES/MGMT      2452
# 234296           ADULT PROBATION DEPT.      1567
# 234297  AMBULATORY COMMUNITY HLTH NTWK      5296
# 234298  JUVENILE TEMPORARY DETENT.CNTR        48
#
#                            Job Title  Base Pay  Position ID  \
# 234294    Assistant State's Attorney 19,001.95      9510048
# 234295         Operating Engineer II 27,098.40      9502511
# 234296  Adult Probation Officer- PSB 19,217.40      9512421
# 234297             Medical Assistant  9,698.80      9519643
# 234298  Administrative Assistant III 12,872.44      1400088
#
#                          Employee Identifier Original Hire Date
# 234294  ac4574b1-d301-44a7-a220-d3aafb5e9ec3         2013-01-28
# 234295  9839f658-99a7-4b0c-a338-411d2fc2e8c9         1988-01-05
# 234296  709a5fed-c9a2-4fe6-9d4d-439bd389b5b8         1985-07-01
# 234297  8967b2f6-c6eb-40b6-836b-f52c6954325c         2016-08-08
# 234298  286c35d5-ca24-4ea7-bb7f-39dff92f78a4         2011-06-06

# %%
# Random 10 samples
Employee_payroll.sample(10)
# Out:
#         Fiscal Year  Fiscal Quarter Fiscal Period First Name      Last Name  \
# 174053         2016               4        2016Q4      HARRY        WHEELER
# 197082         2018               2        2018Q2     NAYOMI           GONU
# 119621         2016               2        2016Q2     STELLA         OKOTIE
# 231339         2018               2        2018Q2     JOSEPH       VERTUCCI
# 166733         2016               4        2016Q4   PATRICIA           VAIS
# 199270         2018               2        2018Q2     DALINA        MOREIRA
# 9768           2017               1        2017Q1    REBECCA      BARCHFELD
# 133874         2016               2        2016Q2   JENNIFER  RAVIN FRETZIN
# 31001          2016               1        2016Q1    LISETTE        COLLAZO
# 127706         2016               1        2016Q1    REBECCA         PEYTON
#
#        Middle Init                          Bureau   Office  \
# 174053           L                         Sheriff 1,239.00
# 197082         NaN                          HEALTH 1,240.00
# 119621         NaN                Bureau of Health 4,897.00
# 231339           A                       CORPORATE 1,214.00
# 166733           A                 Public Defender 1,260.00
# 199270         NaN  AMBULATORY COMMUNITY HLTH NTWK 4,893.00
# 9768           NaN                Bureau of Health 4,897.00
# 133874         NaN                State's Attorney 1,250.00
# 31001          NaN                         Sheriff 1,239.00
# 127706           J                Bureau of Health 4,890.00
#
#                            Office Name  Job Code  \
# 174053       DEPARTMENT OF CORRECTIONS      1361
# 197082          Cermak Health Services      6823
# 119621   STROGER HOSPITAL OF COOK CNTY      1942
# 231339              Sheriff Admin & HR      1328
# 166733                 PUBLIC DEFENDER       606
# 199270  AMBULATORY COMMUNITY HLTH NTWK      5296
# 9768     STROGER HOSPITAL OF COOK CNTY      3993
# 133874                 STATES ATTORNEY      1172
# 31001        DEPARTMENT OF CORRECTIONS      1360
# 127706                BUREAU OF HEALTH      1982
#
#                              Job Title  Base Pay  Position ID  \
# 174053           Correctional Sergeant      0.00      9506453
# 197082            Ward Clerk (SEIU 73)  7,247.74      1803263
# 119621               Clinical Nurse II 25,704.00      9524052
# 231339           County Police Officer 17,985.43      1803355
# 166733   Assistant Public Defender III 15,866.52      9511287
# 199270               Medical Assistant 11,074.47      1600149
# 9768    APN-Cert Reg Nurse Anesthetist 34,242.18       903983
# 133874      Assistant State's Attorney 32,734.23      9509729
# 31001             Correctional Officer 15,278.99      9506872
# 127706               Master Instructer      0.00       300281
#
#                          Employee Identifier Original Hire Date
# 174053  fe663fda-701a-4459-9eb8-6e97bd46ef78         1995-05-01
# 197082  1ee85f55-debf-4b5b-a74f-88f9edf59e43         1999-01-19
# 119621  b185599a-dd1d-4c39-b153-3116bd0aeb89         2005-11-28
# 231339  28e65515-ba79-46be-9c27-ad977b3042e6         2007-07-23
# 166733  715606d7-4912-4574-bc21-f892bdf48b55         2004-06-28
# 199270  e6fd98bf-0fe5-4c2c-8026-8af6f9a5c602         2016-08-22
# 9768    6c59e48e-e8d2-4c22-81c3-2a2572453a92         2013-11-18
# 133874  d242d7e8-4899-43ba-af24-f9cfd9600c02         1994-09-19
# 31001   2dfde5b9-531f-492c-a8cc-ef161e169774         2001-10-01
# 127706  d8c234cd-dce5-47d8-8b6f-efdef95a5692         1983-09-12

# %%
# Checking the dimension of dataset 
Employee_payroll.shape
# Out:
# (234299, 15)

# %%
# Name of the columns
Employee_payroll.columns
# Out:
# Index(['Fiscal Year', 'Fiscal Quarter', 'Fiscal Period', 'First Name',
#        'Last Name', 'Middle Init', 'Bureau', 'Office', 'Office Name',
#        'Job Code', 'Job Title', 'Base Pay', 'Position ID',
#        'Employee Identifier', 'Original Hire Date'],
#       dtype='object')

# %%
# Describes the numerical variables
Employee_payroll.describe()
# Out:
#        Fiscal Year  Fiscal Quarter     Office   Job Code   Base Pay  \
# count   234,299.00      234,299.00 231,115.00 234,299.00 234,295.00
# mean      2,016.83            2.26   2,268.64   2,236.13  16,795.43
# std           0.77            1.09   1,611.80   1,926.40  10,716.17
# min       2,016.00            1.00   1,002.00       1.00 -19,562.15
# 25%       2,016.00            1.00   1,239.00   1,172.00  11,490.95
# 50%       2,017.00            2.00   1,280.00   1,360.00  15,826.42
# 75%       2,017.00            3.00   4,890.00   2,381.00  20,396.43
# max       2,018.00            4.00   4,898.00   8,097.00 242,576.34
#
#        Position ID
# count   234,299.00
# mean  7,309,608.32
# std   3,745,044.93
# min          47.00
# 25%   1,803,613.00
# 50%   9,508,001.00
# 75%   9,516,444.50
# max   9,935,320.00

# %%
# Converting the format of numeric features
pd.options.display.float_format = '{:,.2f}'.format

# %%
# Checking after the format change
Employee_payroll.describe()
# Out:
#        Fiscal Year  Fiscal Quarter     Office   Job Code   Base Pay  \
# count   234,299.00      234,299.00 231,115.00 234,299.00 234,295.00
# mean      2,016.83            2.26   2,268.64   2,236.13  16,795.43
# std           0.77            1.09   1,611.80   1,926.40  10,716.17
# min       2,016.00            1.00   1,002.00       1.00 -19,562.15
# 25%       2,016.00            1.00   1,239.00   1,172.00  11,490.95
# 50%       2,017.00            2.00   1,280.00   1,360.00  15,826.42
# 75%       2,017.00            3.00   4,890.00   2,381.00  20,396.43
# max       2,018.00            4.00   4,898.00   8,097.00 242,576.34
#
#        Position ID
# count   234,299.00
# mean  7,309,608.32
# std   3,745,044.93
# min          47.00
# 25%   1,803,613.00
# 50%   9,508,001.00
# 75%   9,516,444.50
# max   9,935,320.00

# %%
# Describes the categorical features
Employee_payroll.describe(include='O')
# Out:
#        Fiscal Period First Name Last Name Middle Init            Bureau  \
# count         234299     234299    234299      140887            234299
# unique            10       6880     13251         287               111
# top           2018Q1    MICHAEL   JOHNSON           M  Bureau of Health
# freq           26539       4682      2051       18266             53903
#
#                       Office Name             Job Title  \
# count                      231115                234299
# unique                        160                  2382
# top     DEPARTMENT OF CORRECTIONS  Correctional Officer
# freq                        40534                 34435
#
#                          Employee Identifier
# count                                 234299
# unique                                 28375
# top     2682a053-127a-4ce2-affa-ead00c86c053
# freq                                      17

# %%
# summary of the dataset
Employee_payroll.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 234299 entries, 0 to 234298
# Data columns (total 15 columns):
#  #   Column               Non-Null Count   Dtype
# ---  ------               --------------   -----
#  0   Fiscal Year          234299 non-null  int64
#  1   Fiscal Quarter       234299 non-null  int64
#  2   Fiscal Period        234299 non-null  object
#  3   First Name           234299 non-null  object
#  4   Last Name            234299 non-null  object
#  5   Middle Init          140887 non-null  object
#  6   Bureau               234299 non-null  object
#  7   Office               231115 non-null  float64
#  8   Office Name          231115 non-null  object
#  9   Job Code             234299 non-null  int64
#  10  Job Title            234299 non-null  object
#  11  Base Pay             234295 non-null  float64
#  12  Position ID          234299 non-null  int64
#  13  Employee Identifier  234299 non-null  object
#  14  Original Hire Date   234299 non-null  datetime64[ns]
# dtypes: datetime64[ns](1), float64(2), int64(4), object(8)
# memory usage: 26.8+ MB

# %%
# Describes the all variables
Employee_payroll.describe(include='all')
# Out:
# <ipython-input-83-2f11d2cf785b>:2: FutureWarning: Treating datetime data as categorical rather than numeric in `.describe` is deprecated and will be removed in a future version of pandas. Specify `datetime_is_numeric=True` to silence this warning and adopt the future behavior now.
#   Employee_payroll.describe(include='all')
#         Fiscal Year  Fiscal Quarter Fiscal Period First Name Last Name  \
# count    234,299.00      234,299.00        234299     234299    234299
# unique          NaN             NaN            10       6880     13251
# top             NaN             NaN        2018Q1    MICHAEL   JOHNSON
# freq            NaN             NaN         26539       4682      2051
# first           NaN             NaN           NaN        NaN       NaN
# last            NaN             NaN           NaN        NaN       NaN
# mean       2,016.83            2.26           NaN        NaN       NaN
# std            0.77            1.09           NaN        NaN       NaN
# min        2,016.00            1.00           NaN        NaN       NaN
# 25%        2,016.00            1.00           NaN        NaN       NaN
# 50%        2,017.00            2.00           NaN        NaN       NaN
# 75%        2,017.00            3.00           NaN        NaN       NaN
# max        2,018.00            4.00           NaN        NaN       NaN
#
#        Middle Init            Bureau     Office                Office Name  \
# count       140887            234299 231,115.00                     231115
# unique         287               111        NaN                        160
# top              M  Bureau of Health        NaN  DEPARTMENT OF CORRECTIONS
# freq         18266             53903        NaN                      40534
# first          NaN               NaN        NaN                        NaN
# last           NaN               NaN        NaN                        NaN
# mean           NaN               NaN   2,268.64                        NaN
# std            NaN               NaN   1,611.80                        NaN
# min            NaN               NaN   1,002.00                        NaN
# 25%            NaN               NaN   1,239.00                        NaN
# 50%            NaN               NaN   1,280.00                        NaN
# 75%            NaN               NaN   4,890.00                        NaN
# max            NaN               NaN   4,898.00                        NaN
#
#          Job Code             Job Title   Base Pay  Position ID  \
# count  234,299.00                234299 234,295.00   234,299.00
# unique        NaN                  2382        NaN          NaN
# top           NaN  Correctional Officer        NaN          NaN
# freq          NaN                 34435        NaN          NaN
# first         NaN                   NaN        NaN          NaN
# last          NaN                   NaN        NaN          NaN
# mean     2,236.13                   NaN  16,795.43 7,309,608.32
# std      1,926.40                   NaN  10,716.17 3,745,044.93
# min          1.00                   NaN -19,562.15        47.00
# 25%      1,172.00                   NaN  11,490.95 1,803,613.00
# 50%      1,360.00                   NaN  15,826.42 9,508,001.00
# 75%      2,381.00                   NaN  20,396.43 9,516,444.50
# max      8,097.00                   NaN 242,576.34 9,935,320.00
#
#                          Employee Identifier   Original Hire Date
# count                                 234299               234299
# unique                                 28375                 3854
# top     2682a053-127a-4ce2-affa-ead00c86c053  2015-07-01 00:00:00
# freq                                      17                  993
# first                                    NaN  1958-07-15 00:00:00
# last                                     NaN  2018-05-21 00:00:00
# mean                                     NaN                  NaN
# std                                      NaN                  NaN
# min                                      NaN                  NaN
# 25%                                      NaN                  NaN
# 50%                                      NaN                  NaN
# 75%                                      NaN                  NaN
# max                                      NaN                  NaN

# %%
# Check for duplciate values in dataset
Employee_payroll.duplicated().any()
# Out:
# False

# %%
# sum of duplicate values
Employee_payroll.duplicated().sum()
# Out:
# 0

# %%
# Check for the null values in dataset
Employee_payroll.isnull().sum()
# Out:
# Fiscal Year                0
# Fiscal Quarter             0
# Fiscal Period              0
# First Name                 0
# Last Name                  0
# Middle Init            93412
# Bureau                     0
# Office                  3184
# Office Name             3184
# Job Code                   0
# Job Title                  0
# Base Pay                   4
# Position ID                0
# Employee Identifier        0
# Original Hire Date         0
# dtype: int64

# %%
# creating function to find percentage of null values
def FindMissingColsPercentage(df):

    total = 0
    for col in df.columns:
        missing_vals = df[col].isnull().sum()
        # mean = sum / total
        pct = df[col].isnull().mean() * 100 
        if missing_vals != 0:
          print('{} => {} [{}%]'.format(col, df[col].isnull().sum(), round(pct, 2)))
        total += missing_vals
    
    if total == 0:
        print("no missing values")

# %%
# Check for the percentage of null values
FindMissingColsPercentage(Employee_payroll)
# Out:
# Middle_Init => 93412 [39.87%]
# Office => 3184 [1.36%]
# Office_Name => 3184 [1.36%]
# Base_Pay => 4 [0.0%]

# %%
# Make a change in column names
Employee_payroll.columns = Employee_payroll.columns.str.replace(' ', "_")

# %%
# Showing the change
Employee_payroll.columns
# Out:
# Index(['Fiscal_Year', 'Fiscal_Quarter', 'Fiscal_Period', 'First_Name',
#        'Last_Name', 'Middle_Init', 'Bureau', 'Office', 'Office_Name',
#        'Job_Code', 'Job_Title', 'Base_Pay', 'Position_ID',
#        'Employee_Identifier', 'Original_Hire_Date'],
#       dtype='object')

# %%
# Checking the unique values in all features
Employee_payroll.nunique()
# Out:
# Fiscal_Year                 3
# Fiscal_Quarter              4
# Fiscal_Period              10
# First_Name               6880
# Last_Name               13251
# Middle_Init               287
# Bureau                    111
# Office                    133
# Office_Name               160
# Job_Code                 2382
# Job_Title                2382
# Base_Pay               121504
# Position_ID             28918
# Employee_Identifier     28375
# Original_Hire_Date       3854
# dtype: int64

# %%
# finding the unique values of "Base_Pay" Column and storing it in "basepay_unique" variable
basepay_unique = Employee_payroll["Base_Pay"].unique()

# %%
# Sorting the basepay_unique variable
sorted(basepay_unique)

# On checking the data in the CSV format we found out that there is people with 0 base pay but it is not being shown below.
# Out:
# [-19562.15,
#  -6004.18,
#  -5971.39,
#  -4065.94,
#  -1729.41,
#  -1154.54,
#  54.56,
#  93.16,
#  170.02,
#  186.66,
#  250.0,
#  266.71,
#  468.49,
#  496.21,
#  517.82,
#  545.9,
#  591.36,
#  640.26,
#  658.79,
#  668.88,
#  890.21,
#  912.95,
#  1034.15,
#  1173.31,
#  1213.8,
#  1282.92,
#  1287.12,
#  1304.2,
#  1307.44,
#  1329.64,
#  1340.89,
#  1407.72,
#  1425.78,
#  1474.85,
#  1489.62,
#  1560.98,
#  1590.8,
#  1625.19,
#  1765.8,
#  1816.42,
#  1824.81,
#  1882.01,
#  1913.58,
#  1917.28,
#  1940.73,
#  1964.71,
#  2039.33,
#  2091.11,
#  2115.28,
#  2130.31,
#  2175.57,
#  2198.49,
#  2207.2,
#  2300.06,
#  2360.51,
#  2424.19,
#  2529.32,
#  2581.64,
#  2674.24,
#  2679.05,
#  2682.2,
#  2717.37,
#  2719.8,
#  2720.5,
#  2737.01,
#  2800.83,
#  2803.92,
#  2891.64,
#  2918.0,
#  2922.6,
#  2957.32,
#  2965.83,
#  2969.19,
#  2985.62,
#  3031.5,
#  3077.38,
#  3100.0,
#  3110.37,
#  3148.55,
#  3149.0,
#  3178.45,
#  3193.3,
#  3232.63,
#  3258.32,
#  3302.0,
#  3349.04,
#  3381.08,
#  3409.7,
#  3464.08,
#  3469.07,
#  3481.86,
#  3498.4,
#  3503.69,
#  3511.29,
#  3516.19,
#  3517.38,
#  3547.25,
#  3568.8,
#  3588.48,
#  3619.3,
#  3636.91,
#  3653.25,
#  3714.47,
#  3719.04,
#  3726.75,
#  3738.85,
#  3807.06,
#  3862.02,
#  3890.56,
#  3928.81,
#  3930.62,
#  3991.26,
#  4000.65,
#  4065.6,
#  4097.48,
#  4106.52,
#  4106.88,
#  4114.23,
#  4197.49,
#  4222.2,
#  4225.8,
#  4268.74,
#  4274.55,
#  4282.0,
#  4285.44,
#  4287.36,
#  4288.0,
#  4288.06,
#  4290.22,
#  4337.48,
#  4361.88,
#  4368.33,
#  4426.26,
#  4468.34,
#  4479.61,
#  4481.79,
#  4494.45,
#  4524.0,
#  4605.2,
#  4610.51,
#  4677.78,
#  4682.11,
#  4731.0,
#  4748.42,
#  4758.65,
#  4758.72,
#  4806.0,
#  4901.91,
#  4970.59,
#  4977.4,
#  4990.51,
#  5012.8,
#  5036.42,
#  5055.68,
#  5172.28,
#  5207.19,
#  5328.24,
#  5334.5,
#  5338.67,
#  5342.92,
#  5378.15,
#  5441.0,
#  5497.5,
#  5511.28,
#  5516.94,
#  5547.9,
#  5567.19,
#  5586.87,
#  5613.29,
#  5625.6,
#  5666.47,
#  5677.98,
#  5692.47,
#  5733.19,
#  5739.46,
#  5750.68,
#  5792.96,
#  5803.2,
#  5831.67,
#  5849.91,
#  5928.78,
#  5947.99,
#  5985.65,
#  5987.96,
#  6009.2,
#  6017.77,
#  6019.73,
#  6038.57,
#  6065.28,
#  6115.59,
#  6129.21,
#  6160.87,
#  6173.21,
#  6181.94,
#  6220.39,
#  6227.2,
#  6278.4,
#  6287.4,
#  6291.34,
#  6298.12,
#  6324.91,
#  6379.8,
#  6384.41,
#  6460.4,
#  6475.01,
#  6486.36,
#  6514.6,
#  6529.43,
#  6596.25,
#  6658.59,
#  6739.2,
#  6746.57,
#  6768.18,
#  6792.0,
#  6795.54,
#  6867.08,
#  6923.06,
#  6949.26,
#  6982.22,
#  6997.94,
#  7068.53,
#  7114.6,
#  7116.62,
#  7116.63,
#  7135.55,
#  7155.31,
#  7193.71,
#  7211.07,
#  7238.94,
#  7285.65,
#  7288.0,
#  7301.03,
#  7365.6,
#  7369.65,
#  7399.92,
#  7403.14,
#  7403.99,
#  7437.61,
#  7440.4,
#  7484.54,
#  7493.49,
#  7548.25,
#  7550.14,
#  7574.52,
#  7600.0,
#  7605.39,
#  7629.66,
#  7630.77,
#  7674.71,
#  7706.1,
#  7718.66,
#  7724.18,
#  7724.64,
#  7733.45,
#  7746.6,
#  7773.34,
#  7800.24,
#  7843.79,
#  7858.53,
#  7868.87,
#  7880.26,
#  7893.22,
#  7920.18,
#  7936.74,
#  7974.87,
#  8000.05,
#  8006.96,
#  8022.89,
#  8034.92,
#  8050.11,
#  8061.03,
#  8067.63,
#  8114.59,
#  8121.33,
#  8121.6,
#  8128.62,
#  8151.06,
#  8173.45,
#  8174.45,
#  8175.93,
#  8206.06,
#  8213.21,
#  8214.68,
#  8276.46,
#  8277.98,
#  8285.8,
#  8295.05,
#  8303.04,
#  8310.09,
#  8312.98,
#  8316.44,
#  8352.28,
#  8353.55,
#  8401.0,
#  8447.98,
#  8467.21,
#  8473.87,
#  8541.7,
#  8598.7,
#  8616.36,
#  8617.65,
#  8630.79,
#  8637.79,
#  8667.01,
#  8669.48,
#  8682.92,
#  8696.62,
#  8710.4,
#  8729.64,
#  8732.72,
#  8757.12,
#  8785.92,
#  8789.88,
#  8796.0,
#  8799.84,
#  8800.18,
#  8800.76,
#  8802.2,
#  8804.79,
#  8813.22,
#  8837.88,
#  8848.57,
#  8857.08,
#  8867.24,
#  8874.09,
#  8878.0,
#  8912.78,
#  8917.57,
#  8933.6,
#  8940.27,
#  8940.63,
#  8959.35,
#  8960.15,
#  8965.97,
#  8966.23,
#  8970.88,
#  8977.3,
#  8977.77,
#  8999.1,
#  9060.65,
#  9064.72,
#  9077.62,
#  9095.43,
#  9118.4,
#  9120.24,
#  9135.52,
#  9137.77,
#  9138.19,
#  9145.51,
#  9151.65,
#  9159.5,
#  9160.93,
#  9163.2,
#  9167.05,
#  9176.2,
#  9220.4,
#  9238.01,
#  9266.69,
#  9291.41,
#  9297.03,
#  9318.58,
#  9324.57,
#  9325.6,
#  9330.09,
#  9334.88,
#  9336.06,
#  9340.21,
#  9342.07,
#  9393.93,
#  9394.2,
#  9402.15,
#  9405.51,
#  9432.97,
#  9440.22,
#  9443.03,
#  9460.72,
#  9466.46,
#  9470.14,
#  9509.76,
#  9511.58,
#  9517.61,
#  9578.15,
#  9588.19,
#  9593.8,
#  9602.53,
#  9606.02,
#  9630.83,
#  9646.07,
#  9663.61,
#  9699.52,
#  9728.66,
#  9757.06,
#  9759.27,
#  9760.87,
#  9772.71,
#  9808.48,
#  9819.85,
#  9841.3,
#  9842.79,
#  9846.2,
#  9847.2,
#  9866.74,
#  9870.56,
#  9872.19,
#  9875.63,
#  9876.13,
#  9882.4,
#  9886.11,
#  9891.68,
#  9895.91,
#  9931.95,
#  9938.8,
#  9944.98,
#  9951.36,
#  9971.04,
#  9978.37,
#  9982.59,
#  9985.65,
#  9985.94,
#  10002.31,
#  10010.61,
#  10050.94,
#  10053.0,
#  10069.71,
#  10070.5,
#  10071.03,
#  10072.24,
#  10103.86,
#  10110.09,
#  10114.97,
#  10118.95,
#  10119.7,
#  10121.18,
#  10124.47,
#  10143.07,
#  10151.5,
#  10159.24,
#  10161.14,
#  10162.29,
#  10164.82,
#  10191.4,
#  10200.34,
#  10201.23,
#  10207.6,
#  10213.1,
#  10216.52,
#  10247.02,
#  10250.61,
#  10260.88,
#  10271.8,
#  10276.39,
#  10294.74,
#  10311.09,
#  10328.25,
#  10333.24,
#  10348.47,
#  10395.34,
#  10416.27,
#  10418.59,
#  10426.2,
#  10429.37,
#  10430.07,
#  10442.34,
#  10443.9,
#  10447.8,
#  10464.4,
#  10501.67,
#  10503.51,
#  10509.82,
#  10525.6,
#  10535.53,
#  10546.48,
#  10572.13,
#  10585.39,
#  10595.2,
#  10596.19,
#  10601.28,
#  10607.11,
#  10636.89,
#  10643.56,
#  10664.4,
#  10667.54,
#  10671.59,
#  10674.02,
#  10681.18,
#  10681.52,
#  10689.23,
#  10727.95,
#  10728.89,
#  10740.45,
#  10740.71,
#  10751.22,
#  10759.98,
#  10764.0,
#  10770.81,
#  10770.91,
#  10772.31,
#  10790.0,
#  10799.82,
#  10801.73,
#  10803.36,
#  10811.15,
#  10835.54,
#  10835.56,
#  10843.14,
#  10846.55,
#  10864.12,
#  10868.03,
#  10883.17,
#  10884.81,
#  10893.19,
#  10906.27,
#  10920.52,
#  10934.25,
#  10937.2,
#  10953.77,
#  10970.11,
#  10971.92,
#  10973.21,
#  10987.61,
#  10997.83,
#  11008.01,
#  11018.02,
#  11031.26,
#  11052.45,
#  11075.81,
#  11099.71,
#  11103.68,
#  11103.94,
#  11107.43,
#  11110.26,
#  11113.32,
#  11113.75,
#  11140.91,
#  11143.8,
#  11146.48,
#  11149.15,
#  11151.65,
#  11162.54,
#  11180.19,
#  11180.3,
#  11184.46,
#  11201.55,
#  11203.19,
#  11221.15,
#  11226.1,
#  11229.41,
#  11229.76,
#  11241.4,
#  11253.67,
#  11253.86,
#  11267.13,
#  11288.95,
#  11299.81,
#  11305.72,
#  11309.7,
#  11310.76,
#  11323.91,
#  11327.12,
#  11329.99,
#  11344.9,
#  11346.86,
#  11353.82,
#  11354.57,
#  11385.76,
#  11393.09,
#  11396.85,
#  11398.66,
#  11412.21,
#  11417.72,
#  11419.77,
#  11434.23,
#  11450.37,
#  11457.45,
#  11463.0,
#  11468.23,
#  11470.3,
#  11471.86,
#  11474.13,
#  11474.76,
#  11479.32,
#  11480.89,
#  11488.78,
#  11488.79,
#  11490.43,
#  11519.46,
#  11524.45,
#  11541.65,
#  11541.75,
#  11553.8,
#  11554.91,
#  11560.12,
#  11591.91,
#  11616.82,
#  11628.12,
#  11629.28,
#  11631.35,
#  11632.66,
#  11633.24,
#  11655.27,
#  11677.32,
#  11692.02,
#  11696.7,
#  11737.8,
#  11739.75,
#  11766.0,
#  11769.38,
#  11773.05,
#  11780.91,
#  11787.73,
#  11791.19,
#  11793.58,
#  11796.51,
#  11798.13,
#  11818.66,
#  11838.76,
#  11862.08,
#  11869.09,
#  11876.42,
#  11877.42,
#  11885.37,
#  11886.55,
#  11896.37,
#  11906.05,
#  11909.83,
#  11925.45,
#  11954.3,
#  11968.65,
#  11992.83,
#  11997.17,
#  12009.69,
#  12021.1,
#  12023.51,
#  12023.57,
#  12038.22,
#  12042.8,
#  12052.66,
#  12063.08,
#  12072.34,
#  12075.85,
#  12077.12,
#  12077.92,
#  12083.29,
#  12087.36,
#  12094.24,
#  12096.99,
#  12105.21,
#  12140.54,
#  12160.41,
#  12167.58,
#  12168.72,
#  12175.49,
#  12187.67,
#  12198.05,
#  12198.7,
#  12219.74,
#  12224.7,
#  12231.21,
#  12234.75,
#  12236.47,
#  12238.97,
#  12242.88,
#  12247.31,
#  12251.37,
#  12254.25,
#  12259.8,
#  12270.72,
#  12278.84,
#  12286.54,
#  12307.32,
#  12318.89,
#  12323.29,
#  12327.42,
#  12331.73,
#  12354.29,
#  12365.93,
#  12369.43,
#  12392.99,
#  12394.63,
#  12398.94,
#  12402.04,
#  12410.82,
#  12417.79,
#  12427.42,
#  12431.64,
#  12442.12,
#  12443.52,
#  12445.02,
#  12459.68,
#  12473.58,
#  12482.27,
#  12482.57,
#  12482.71,
#  12493.38,
#  12501.57,
#  12505.39,
#  12507.92,
#  12521.31,
#  12524.76,
#  12526.33,
#  12531.31,
#  12534.27,
#  12543.09,
#  12547.73,
#  12549.73,
#  12550.28,
#  12580.13,
#  12593.63,
#  12608.22,
#  12612.63,
#  12622.43,
#  12625.36,
#  12642.0,
#  12648.41,
#  12651.48,
#  12656.44,
#  12656.78,
#  12659.49,
#  12674.61,
#  12686.38,
#  12698.36,
#  12714.59,
#  12715.34,
#  12740.55,
#  12742.72,
#  12744.18,
#  12746.8,
#  12754.98,
#  12757.0,
#  12758.07,
#  12758.85,
#  12781.66,
#  12784.4,
#  12801.53,
#  12806.36,
#  12823.17,
#  12829.18,
#  12837.19,
#  12860.04,
#  12863.35,
#  12863.6,
#  12873.6,
#  12884.72,
#  12890.05,
#  12895.15,
#  12922.68,
#  12928.64,
#  12935.5,
#  12936.21,
#  12943.12,
#  12948.55,
#  12954.99,
#  12956.33,
#  12974.36,
#  12983.74,
#  13010.15,
#  13016.82,
#  13018.57,
#  13026.79,
#  13036.0,
#  13037.95,
#  13058.48,
#  13059.56,
#  13062.28,
#  13066.04,
#  13076.64,
#  13081.57,
#  13089.73,
#  13091.36,
#  13091.73,
#  13094.84,
#  13097.01,
#  13097.26,
#  13099.38,
#  13129.12,
#  13130.86,
#  13158.12,
#  13163.03,
#  13167.66,
#  13203.14,
#  13212.85,
#  13228.96,
#  13269.91,
#  13277.2,
#  13278.38,
#  13281.16,
#  13284.4,
#  13300.51,
#  13331.06,
#  13333.85,
#  13348.84,
#  13350.31,
#  13356.76,
#  13362.08,
#  13370.47,
#  13409.41,
#  13412.63,
#  13413.39,
#  13441.86,
#  13441.92,
#  13442.87,
#  13447.06,
#  13456.8,
#  13468.89,
#  13469.67,
#  13474.9,
#  13487.48,
#  13487.54,
#  13490.4,
#  13507.38,
#  13519.71,
#  13528.12,
#  13532.93,
#  13546.09,
#  13548.3,
#  13548.97,
#  13561.33,
#  13562.35,
#  13565.69,
#  13571.3,
#  13582.38,
#  13583.79,
#  13613.55,
#  13615.8,
#  13617.06,
#  13630.78,
#  13642.86,
#  13696.79,
#  13709.91,
#  13716.43,
#  13718.11,
#  13719.14,
#  13722.01,
#  13728.19,
#  13730.8,
#  13736.08,
#  13739.72,
#  13739.93,
#  13740.33,
#  13741.22,
#  13741.54,
#  13744.05,
#  13746.12,
#  13773.88,
#  13797.32,
#  13807.5,
#  13835.57,
#  13847.71,
#  13849.16,
#  13870.1,
#  13870.81,
#  13887.4,
#  13891.72,
#  13917.04,
#  13920.01,
#  13921.0,
#  13929.97,
#  13932.4,
#  13933.24,
#  13943.29,
#  13948.51,
#  13948.8,
#  13950.09,
#  13959.04,
#  13959.5,
#  13962.15,
#  14011.35,
#  14020.9,
#  14026.32,
#  14026.81,
#  14028.94,
#  14051.2,
#  14060.68,
#  14062.99,
#  14066.64,
#  14066.88,
#  14066.98,
#  14070.79,
#  14076.6,
#  14087.7,
#  14109.45,
#  14121.3,
#  14130.31,
#  14130.65,
#  14140.55,
#  14143.16,
#  14147.26,
#  14153.92,
#  14158.19,
#  14160.57,
#  14164.86,
#  14173.25,
#  14178.38,
#  14205.51,
#  14213.02,
#  14218.8,
#  14230.94,
#  14243.08,
#  14249.16,
#  14290.97,
#  14291.18,
#  14303.1,
#  14303.33,
#  14306.44,
#  14316.58,
#  14344.06,
#  14351.02,
#  14375.91,
#  14382.01,
#  14389.59,
#  14395.47,
#  14404.16,
#  14432.35,
#  14451.27,
#  14473.0,
#  14480.19,
#  14484.11,
#  14488.46,
#  14512.58,
#  14516.32,
#  14522.39,
#  14525.78,
#  14539.51,
#  14545.43,
#  14546.5,
#  14548.66,
#  14549.43,
#  14554.96,
#  14562.01,
#  14574.22,
#  14576.82,
#  14578.8,
#  14581.21,
#  14590.08,
#  14598.89,
#  14606.56,
#  14607.06,
#  14614.79,
#  14617.55,
#  14617.63,
#  14632.1,
#  14652.34,
#  14662.05,
#  14668.21,
#  14670.01,
#  14692.8,
#  14704.83,
#  14706.76,
#  14725.62,
#  14749.38,
#  14750.34,
#  14763.02,
#  14767.79,
#  14772.95,
#  14782.55,
#  14784.64,
#  14797.2,
#  14798.68,
#  14800.79,
#  14808.25,
#  14814.11,
#  14815.63,
#  14838.44,
#  14858.08,
#  14860.59,
#  14862.59,
#  14872.18,
#  14893.21,
#  14906.93,
#  14907.15,
#  14917.73,
#  14923.6,
#  14926.66,
#  14928.78,
#  14930.42,
#  14963.54,
#  14977.83,
#  14987.15,
#  14992.07,
#  14993.61,
#  14993.69,
#  15000.41,
#  15003.38,
#  15010.51,
#  15019.42,
#  15026.73,
#  15027.27,
#  15031.53,
#  15041.52,
#  15042.74,
#  15061.56,
#  15078.52,
#  15093.18,
#  15101.48,
#  15101.51,
#  15105.88,
#  15106.57,
#  15106.63,
#  15110.18,
#  15123.68,
#  ...]

# %%
# This code shows the observations with 0 base pay
Employee_payroll.loc[Employee_payroll["Base_Pay"]==0]
# Out:
#         Fiscal_Year  Fiscal_Quarter Fiscal_Period First_Name   Last_Name  \
# 66             2016               1        2016Q1      FRANK      ABBOTT
# 68             2016               2        2016Q2     KHALIL      ABBOUD
# 69             2016               3        2016Q3     KHALIL      ABBOUD
# 72             2016               2        2016Q2     HERAND    ABCARIAN
# 92             2017               3        2017Q3   ABDALLAH  ABDELHAMID
# ...             ...             ...           ...        ...         ...
# 229649         2018               2        2018Q2     THOMAS       BONDI
# 230477         2018               2        2018Q2   LILIANNA       KALIN
# 231487         2018               2        2018Q2       RAUL     BARRAZA
# 233666         2018               1        2018Q1    TANESHA       WHITE
# 234147         2018               1        2018Q1    MICHAEL       JONES
#
#        Middle_Init                         Bureau   Office  \
# 66               J               Bureau of Admin. 1,500.00
# 68               E                    Chief Judge 1,280.00
# 69               E                    Chief Judge 1,280.00
# 72             NaN               Bureau of Health 4,897.00
# 92               F                        Sheriff 1,239.00
# ...            ...                            ...      ...
# 229649           R      DEPARTMENT OF CORRECTIONS 1,239.00
# 230477           M                         HEALTH 1,890.00
# 231487         NaN      DEPARTMENT OF CORRECTIONS 1,239.00
# 233666           L      DEPARTMENT OF CORRECTIONS 1,239.00
# 234147           D  STROGER HOSPITAL OF COOK CNTY 4,897.00
#
#                            Office_Name  Job_Code                    Job_Title  \
# 66      DEPT. OF TRANSPORTATION AND HW       431        Right of Way Agent II
# 68               ADULT PROBATION DEPT.      1564   Supervisor Adult Probation
# 69               ADULT PROBATION DEPT.      1564   Supervisor Adult Probation
# 72       STROGER HOSPITAL OF COOK CNTY      1649     Medical Div Chairman XII
# 92           DEPARTMENT OF CORRECTIONS      1360         Correctional Officer
# ...                                ...       ...                          ...
# 229649       DEPARTMENT OF CORRECTIONS      1360         Correctional Officer
# 230477                Bureau of Health      8089   Sr. Labor & Employ Counsel
# 231487       DEPARTMENT OF CORRECTIONS      1360         Correctional Officer
# 233666       DEPARTMENT OF CORRECTIONS      1360         Correctional Officer
# 234147   STROGER HOSPITAL OF COOK CNTY      2417  Hospital Security Officer I
#
#         Base_Pay  Position_ID                   Employee_Identifier  \
# 66          0.00      9517610  f52eb088-72d8-494a-a296-772a71783234
# 68          0.00      9512676  e9a92ee0-120f-41f3-b824-4e4d7c43cc5c
# 69          0.00      9512676  e9a92ee0-120f-41f3-b824-4e4d7c43cc5c
# 72          0.00       800768  e07ba440-b785-4047-ab96-38c9714ce186
# 92          0.00       800096  433c0c09-b58e-45c0-96ee-1cf5c315cf5f
# ...          ...          ...                                   ...
# 229649      0.00      9506963  272c860d-26bf-44f1-96af-3056e4c654c0
# 230477      0.00      1801745  b12f72e8-e349-42d3-9a36-a3bc62dcabc4
# 231487      0.00      9508604  76bb6a7e-c9f8-4752-be7d-b80a568525a8
# 233666      0.00      9508098  58a40df7-f29b-4141-9c52-a08f49e17f14
# 234147      0.00      9520507  9e68518e-c40b-44ec-be2a-0a50d7230e3d
#
#        Original_Hire_Date
# 66             1986-06-20
# 68             1982-12-17
# 69             1982-12-17
# 72             2009-08-17
# 92             2011-06-27
# ...                   ...
# 229649         2012-02-27
# 230477         2006-05-30
# 231487         2012-02-27
# 233666         2002-11-18
# 234147         1990-02-15
#
# [2541 rows x 15 columns]

# %%
# Checking potential Outliers

# Plot the box plot with the Base_Pay feature 
plt.figure(figsize=(20,10))
plt.title("Check Outlier with boxplot for basepay")
Employee_payroll.boxplot(column=['Base_Pay']);

# %%
# Checking the correlation between features
corrmat = Employee_payroll.corr(method='pearson')

sns.set_style("white")

# Mask for the upper triangle
mask = np.zeros_like(corrmat, dtype=bool)
mask[np.triu_indices_from(mask)] = True

# Set figure size
fig, ax = plt.subplots(figsize=(8, 8))

# Define custom colormap
cmap = sns.diverging_palette(220, 10, as_cmap=True)

# Draw the heatmap
sns.heatmap(corrmat, mask=mask, cmap=cmap, vmin=-1, vmax=1, center=0,
            square=True, linewidths=.5, cbar_kws={"shrink": 1}, annot=True,annot_kws={'size': 15})

plt.tight_layout()
fig.show()
